# %% [markdown]
# # Validate that rendered bokeh raw is in linear space

# %%
from pathlib import Path
from PIL import Image
import numpy as np

path = Path("C:/Users/ckobalt/Documents/MasterThesis/Spatially-Varying-Bokeh/bokehConfig/1_rawRenderings/bokeh_fl45.0_as6_samples50_od500_lidx0of8.png")

with Image.open(path) as img:
    arr = np.asarray(img)
    top_row = arr[0]
    top_center = arr[0, arr.shape[1] // 2]

print(top_row)
print(top_center)
# yes.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 7
#       3 import numpy as np
#       5 path = Path("C:/Users/ckobalt/Documents/MasterThesis/Spatially-Varying-Bokeh/bokehConfig/1_rawRenderings/bokeh_fl45.0_as6_samples50_od500_lidx0of8.png")
# ----> 7 with Image.open(path) as img:
#       8     arr = np.asarray(img)
#       9     top_row = arr[0]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\PIL\Image.py:3465, in open(fp, mode, formats)
#    3462     filename = os.fspath(fp)
#    3464 if filename:
# -> 3465     fp = builtins.open(filename, "rb")
#    3466     exclusive_fp = True
#    3467 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ckobalt\\Documents\\MasterThesis\\Spatially-Varying-Bokeh\\bokehConfig\\1_rawRenderings\\bokeh_fl45.0_as6_samples50_od500_lidx0of8.png'
